# %% [markdown]
# # This code is implemented on the Fundus Object

# %%
# Import
import os
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Load local libraries
# ROOT contais the project directory 
os.chdir(os.path.dirname(os.getcwd()))
print(os.getcwd())
# Out:
# /home/ubuntu/master_thesis

# %%
# Local imports
from src.normalize import normalize_folder
from src.Fundus import Fundus

# %%
# Set up logger and othe rimportant stuff
#logger = sl("loger.log")
gq = 'data/normalized/test/female/1000180_21015_0_0.png'
bq = 'data/normalized/test/female/3117767_21015_0_0.png'

# %%
# Read in file
img_gq = cv2.imread(gq)
img_bq = cv2.imread(bq)

plt.matshow(img_gq[:,:,::-1])
plt.axis("off")
plt.matshow(img_bq[:,:,::-1])
plt.axis("off")
# Out:
# (-0.5, 2047.5, 1535.5, -0.5)

# %%
# Transpose the image to get first the color chanels
rg, gg, bg = img_gq.T
rb, gb, bb = img_bq.T
rg.shape
# Out:
# (2048, 1536)

# %%
# Flatten each color channel
rg, gg, bg = rg.flatten(), gg.flatten(), bg.flatten()
rb, gb, bb = rb.flatten(), gb.flatten(), bb.flatten()
rg.shape
# Out:
# (3145728,)

# %%
print(np.mean(bg))
print(np.mean(bb))
# Out:
# 95.53928883870442
# 65.17092959086101

# %%
np.mean(Fundus(bq).b)
# Out:
# 65.17092959086101
